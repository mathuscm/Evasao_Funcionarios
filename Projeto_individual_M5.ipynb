# %% [markdown]
# <a href="https://colab.research.google.com/github/mathuscm/Evasao_Funcionarios/blob/main/Projeto_individual_M5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pessoas deixando a empresa
#
# Você foi contratado como analista de dados e seu chefe, o Chief Marketing
# Officer (CMO), pediu que você trabalhasse com seu Parceiro de Negócios
# de Recursos Humanos (HRBP) para entender o que está causando o
# atrito – pessoas deixando a empresa – em toda a organização de
# marketing e apresentar suas descobertas.
#
# ---
#
# Você deve criar um ou mais dashboards, com o Tableau, identificando as
# razões de saída dos funcionários da empresa e seus impactos, e indicando
# possíveis soluções para esses problemas.
#
# ---

# %% [markdown]
# # 1. O que está sendo mostrado aqui? Escreva um texto explicando os dados. Dica: imagine que você precisa explicar esse gráfico para o seu chefe. Escreva sobre como você faria isso em voz alta (fazendo suposições conforme necessário).

# %% [markdown]
# ![leaving.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# A imagem nos mostra dois gráficos construídos à partir de diferentes abordagens sobre as motivações
# pelas quais as pessoas estão saindo de uma empresa - a primeira, realizando perguntas aos funcionários; a segunda, através do formulário de saída (que pode ser anônimo).
#
# A métrica dos gráficos é escalada em Nível de Impacto (eixo Y) e Frequencia (eixo X)
#
# * O primeiro gráfico realizado com o nosso parceiro de recursos humanos nos mostra que:
#
# As motivações mais impactantes, porém não tão frequentes:
# - Treinamento (31),
# - Conflito com outros (11),
# - falta de Reconhecimento (65),
# - Carga horária (14),
# - Pagamento (16)
#
# * Em ordem de impacto e não por quantidade de evasão
#
# A representação visual foi feita no modelo do gráfico de bolhas, que em sua totalidade está dividido em quatro
# quadrantes, pertencentes aos dois eixos do gráfico. As bolhas estão distribuidas dentro dos quadrantes conforme
# o "Impacto" e a "Frequência" dos motivos. Os circulos também alteram sua dimensão conforme a quantidade de vezes
# que essas razões são citadas pelos funcionários e os números são inseridos dentro das bolas.
#
# Nos gráficos, as métricas são escaladas da seguinte forma: quando mais a direita, mais frequente é a motivação,
# e quanto mais a esquerda, menor (eixo X).  Quanto mais acima no quadrante, maior é o nível de impacto, quanto mais
# a baixo, menor.
#
# Das razões que foram enquadradas acima como mais impactantes, suas categorias estão elencadas na sequência
# em que descende o gráfico, e neste quadrante superior podemos observar que apesar dos tópicos "Treinamento" e
# "Conflito com Outros" se destacarem em questão de posição, a questão com mais reportes de dispensa foi "Falta de Reconhecimento",
# o que pode significar que o ambiente de trabalho não tenha culturas saudáveis e não seja favorável para seus
# funcionários. O que justificaria também o número do tópico de "Plano de Carreira". Se não há a oportunidade de um plano
# de carreira, esta reclamação está implicitamente entrelaçada na falta de reconhecimento dos seus funcionários.
# A falta de treinamento e ambiente conflitante também se tornam fatores principais de desmotivação dos funcionários, considerando
# que solucionar demandas sem as devidas alternativas ou habilidades e comunicação conturbada durante os processos de trabalham
# geram estresse e esgotamento das pessoas do grupo.
#
# Há também as motivações que são frequentes e de médio impacto, no entanto, valiosas:
# - Plano de carreira,
# - Tipo de trabalho,
# - Realocação
#
# Segundo gráfico realizado a partir do formulário de saída:
#
# As motivações com mais impactos segundo os próprios funcionários:
# - Treinamento(23),
# - Conflito com outros(15),
# - falta de Reconhecimento(44),
# - Carga horária(39),
# - Pagamento(24)
#
# Em ordem de impacto e não por quantidade de evasão
#
# A motivação mais frequente no gráfico Exit Survey é a de plano de carreira(171).
#
# Ao analisar a demonstração visual da entrevista, ele pode ser interpretado nas mesmas intenções, no entanto,
# é importante que nos pequenos detalhes houve certa disparidade no número das respostas para as mesmas justificativas.
#
#
# APANHADO GERAL
#
# Em relação ao impacto os números não se destoam significativamente, já em relação à frequencia houve um esvaziamento
# evidente cuja única posição predominante das motivações frequentes é da Progressão de Carreira.

# %% [markdown]
# # 2. Que observações você pode fazer a partir desses dados? Coloque duas conclusões específicas em palavras. Escreva sentenças completas.
#
# Ambas pesquisas nos apontam fatores de extrema sensibilidade na relação funcionário x empresa, que por vezes são os pilares de sustentação que gera o vínculo entre eles, e o desenvolvimento do funcionário, é por consequência, o desenvolvimento da empresa e vice-versa.
#
# Pontos marcantes que podemos observar são:
#
# 1. Progressão de Carreira: aparece com alta frequência nas duas demonstrações e sua margem de impacto está acima da média, o que indica falta de oportunidades de crescimento interno, gerando falta de perspectiva nos funcionários fazendo com que eles saiam da empresa. Pode ser que seja um ambiente engessado em relação à crescimento ou falte planejamento e gestão para este tipo de processo interno, fazendo com que seja estático. O ideal seria recriar o planejamento de cargos e buscar desenvolver seus funcionários através de treinamentos (que também tem impacto na saída) e projetos para evolução de carreira, dar a oportunidade da perspectiva de realizar seus anseios impulsiona a motivação do trabalhador.
#
# 2. Falta de reconhecimento: este é outro ponto que encontramos vários reports, mesmo com pequena disparidade, há uma frequência moderada e nível de impacto é alto, sugerindo que os funcionários podem estar se sentindo desvalorizados ou não apreciados por suas contribuições à organização. A falta de reconhecimento pode levar à insatisfação e à redução da motivação dos funcionários, o que pode influenciar a perda de talentos. Para este ponto, seria interessante implementar algumas estratégias como feedbacks e oportunidades de destaque para valorizar os funcionários, melhorando a satisfação no trabalho e manter a equipe engajada e motivada.

# %% [markdown]
# # 3. O que não é ideal ou poderia ser evitado na visualização em sua forma atual? Que perguntas você faria ou que feedback daria para quem fez o gráfico? Exemplo: suponha que seu HRBP gastou muito tempo criando esse gráfico; como você pode ajustar seu feedback para que ele não se ofenda?
#
# Ao olhar para o gráfico em sua atual representação, podemos notar que alguns pontos nele podem ser melhorados para termos uma visualização mais clara e objetiva. Alguns pontos que não tornam o tipo de demonstração apropriada:
#
# - As bolas tem dimensões diferentes conforme o número dentro delas, o que faz com que os indicadores com poucos reportes dos funcionários do motivo de saída, trás uma leitura desconfortável, pois fica minuscula;
#
# - Além das dimensões, há muitas cores no gráfico criando dispersão visual, o uso em demasia gera poluição, o que torna a leitura dos valores mais cansativa, já que ao olhar os elementos o leitor precisará constantemente do auxílio das legendas para entender do que se trata, o que dissipa a atenção. Outro ponto é que algumas cores não seriam distinguidas por pessoas daltonicas, por exemplo;
#
# - A construção do gráfico em sí não é clara, os nomes nos eixos estão como 'etiquetas', sendo mais chamativos que informativos. Ainda sobre os eixos, não há referências de valores, como por exemplo Ability to Impact, não tem escala de números que ajudem a justificar a postição dos elementos dentro dos quadrantes, o que pode causar uma leve confusão, já que algumas das motivações citadas têm muita adesão, porém pouco impacto. Sem as referências numéricas corretas a interpretação pode se deturpar.
#
# O gráfico precisa ser intuitivo, excesso de elementos, cores e tamanhos gera confusão e cansaço na leitura.
#
# Com isso em vista, e antes de passar qualquer feedback para o colega, para que ele não se sentisse invalidado, agradeceria a dedicação e o carinho que ele teve em preparar toda a apresentação, elogiando o comprometimento como profissional, e então faria a proposta da gente discutir mais sobre o gráfico, afim de propor melhorias, chamando para refletir sobre a escolha dos elementos e o porquê dos valores se encontrarem dentro das bolhas e não nos eixos, por exemplo.
# Destacaria também que, apesar da boa intenção, talvez as informações não tenham ficado tão claras à primeira vista, retomando os pontos falados acima e sugerindo melhorias como utilizar apenas uma cor nos elementos, colocar os valores de Impacto como régua no eixo vertical para se tornar mais intuitivo, e possivelmente procurar outra maneira de visualização para que os números das respostas dos funcionários ficassem melhor colocados e facilitando a interpretação.

# %% [markdown]
# # 4. Crie três maneiras diferentes de mostrar esses dados e liste quais são algumas vantagens e insuficiências de cada uma.

# %% [markdown]
# ## Gráfico de barras horizontal

# %% [markdown]
# ![horizontal2.jpg](data:image/jpeg;base64,...)![horizontal1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Vantagens:
# - Boa visualização dos rótulos e valores em uma quantidade compacta de dados,
# - boa noção da diferença entre os dados tanto pelas barras quanto pelo eixo horizontal,
# - largura uniforme das barras,
# - eficaz para exibir comparação entre categorias.
#
# Desvantagens:
# - Se não estiver discriminado que o eixo y está em ordem de impacto (do maior 'training' para o menor 'illness') pode prejudicar o manejamento do gráfico, assim como a interpretação e tomada de decisão,
# - se houver muitas categorias a leitura dos rótulos fica prejudicada deixando o texto comprimido e ilegível.

# %% [markdown]
# ## Gráfico de barras vertical tríplice

# %% [markdown]
# ![troca.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Vantagens:
# - Comparação direta dos elementos qualitativo (nível de impacto dos tópicos) e quantitativo (pesquisa do RH e formulário de saída),
# - ênfase à comparação já que ao agrupar os três tipos de dados e diferenciá-los por cor, as discrepancias se tornam mais claras,
#
# - Aproveitamento de espaço, considerando o agrupamento em um só quadrante, não se torna necessário outro gráfico apenas para dois elementos, tornando viualmente mais prático
#
# - Visualização rápida do comportamento dos dados
#
# Desvantagens:
# - Comparação limitada de dados para evitar excessos e não tornar a visualização complexa seja pela quantidade de categorias/barras e distância entre elas,
#
# - É necessário utilizar cores distintas para identificar os diferentes tipos de dados, reiterando a quantidade amigável de dados a serem comparados afim de evitar poluição, pois seria prejudicial para a discriminação e interpretação

# %% [markdown]
# ## Gráfico Tree Map

# %% [markdown]
# ![treemap.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Vantagens:
# - As áreas dos retângulos são proporcionais aos valores que representam, permitindo de maneira mais eficiente a comparação rápida,
#
# - É possível acrescentar os rótulos de categorias e valores correspondentes de cada um
#
# Desvantagens:
# - Visualização complexa, dependendo do número de dados contido nele pode se tornar a amostragem confusa,
#
# - A proporcionalidade entre valores x quadrados pode ser quebrada quando houver muitos dados e confundir a interpretação, vide este mesmo exemplo, se não houvesse os rótulos de valores "Workload", "Career Advancement" e "Pay" seriam interpretados da mesma maneira,
#
# - No tocante aos rótulos, as vezes será possível inserí-los, porém não discriminá-los, como neste gráfico, há o nome da categoria, o número do seu impacto e a quantidade de report; à primeira vista, se não for informado, inviabiliza a interpretação
#
# - Sem rótulos as interpretações tendem a ser intuitivas, o que inviesaria totalmente a análise da proposta
#
# - Comparar valores robustos necessita explicação prévia das variáveis inseridas

# %% [markdown]
# # 5. Qual visualização representa melhor os dados e por quê?

# %% [markdown]
# Acredito que o gráfico de barras tríplice cria uma representação efetiva.
# É importante ressaltar que para realizar sua construção é necessário nos atentar às boas práticas, mesmo que haja poucas desvantagens em relação a ele, elas estão ligadas principalmente a algumas etiquetas que devem ser seguidas para evitar excessos.
#
# - Com este gráfico consigo comparar simultaneamente os três dados que fazem da pesquisa essencial - "Ability to impact" (Impacto), "HRBP" e "Exit survey" - tendo as informações lado a lado a comparação se torna totalmente acessível, permitindo observar as ênfases das variações já que elas se destacam visualmente.
#
# - As categorias, como estão colocadas no cabeçalho, são fáceis de serem lidas; as barras estão identificadas em suas cores através do cartão informativo, o que torna o gráfico legível para outros públicos como a equipe de marketing, gestores e coordenadores, por exemplo
#
# - Entendendo que as categorias estão organizadas em ordem decrescente de impacto, a comparação entre HRBP e Exit Survey pode ser feita de maneira mais precisa

# %% [markdown]
# # 6. Como você pode gerar essas informações em uma história orientada por dados para seu chefe? O objetivo é pensar além de mostrar simplesmente dados e mostrar o contexto da história.
